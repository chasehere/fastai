# %% [markdown]
# # Nature Conservancy Fisheries Contest

# %% [markdown]
# ## Action Plan
# 1. Create Validation and Sample sets
# 2. Rearrange image files into their respective directories
# 3. Finetune and Train model
# 4. Generate predictions
# 5. Validate predictions
# 6. Submit predictions to Kaggle

# %% [markdown]
# ## Boilerplate

# %%
#import modules
from utils import *
from vgg16 import Vgg16

data_path = '/mnt/azurefs/data/fisheries/'
train_path = data_path + 'train/'
test_path = data_path +' test_stg1/'

# %%
batch_size=64

# %% [markdown]
# ## Look at a couple pictures

# %%
vgg = Vgg16()
# Out:
# /home/slaterc/anaconda3/envs/py27/lib/python2.7/site-packages/keras/layers/core.py:621: UserWarning: `output_shape` argument not specified for layer lambda_1 and cannot be automatically inferred with the Theano backend. Defaulting to output shape `(None, 3, 224, 224)` (same as input shape). If the expected output shape is different, specify it via the `output_shape` argument.
#   .format(self.name, input_shape))

# %%
batches = vgg.get_batches(train_path, batch_size=batch_size)
# Out:
# Found 3777 images belonging to 8 classes.

# %%
# %cd $train_path/ALB
g = glob('*.jpg')
# Out:
# /home/slaterc/nbs/data/fisheries/train/ALB

# %%
image_sizes = []
for f in g:
    image_sizes.append(Image.open(f).size)

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(train_path) if isfile(join(train_path, f))]
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-9cd7921a4f3e> in <module>()
#       1 from os import listdir
#       2 from os.path import isfile, join
# ----> 3 onlyfiles = [f for f in listdir(train_path) if isfile(join(train_path, f))]
#
# OSError: [Errno 2] No such file or directory: 'data/fisheries/train'

# %%
import random
random.choice(batches.filenames)
# Out:
# 'OTHER/img_04680.jpg'

# %%
from PIL import Image
#Image.open(train_path + '/ALB/img_06539.jpg')
#Image.open(train_path + '/ALB/img_04848.jpg')
image_path = random.choice(batches.filenames)
print(image_path)
print(Image.open(train_path + image_path).size)
Image.open(train_path + image_path)
# Out:
# ALB/img_06587.jpg
# (1280, 720)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x7FF308807A10>
